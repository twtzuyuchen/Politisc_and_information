# %% [markdown]
# 輸入立委臉書粉專內容及選舉政見資料

# %%
import pandas as pd
fb = pd.read_csv('nysu_10902_2019_research.csv')
politics = pd.read_csv('9th_legislator_promise.csv')

# %% [markdown]
# 以新北市立委黃國昌為例，依照月份來統計數值資料的變化

# %%
fb.head(1)
# Out:
#                             post_id          page_id page_name page_category  \
# 0  244784245612709_2052039854887130  244784245612709       陳學聖          政治人物
#
#                                              message story   type  \
# 0  鑒於中油觀塘案在環評大會迅速通關，原先專案小組考量對藻礁生態有重大影響，建議退回目的事業主管...   NaN  photo
#
#                                            permalink  \
# 0  https://www.facebook.com/244784245612709/posts...
#
#            created_time_gmt  created_time_taipei  ... link_name  \
# 0  2019-01-15T11:00:16+0000  2019-01-15T19:00:16  ...       NaN
#
#   link_description like_count  haha_count  love_count  angry_count  sad_count  \
# 0              NaN        144           0           0            0          0
#
#    wow_count  comment_count  share_count
# 0          0              6            5
#
# [1 rows x 21 columns]

# %%
huang = fb[fb.page_name == "黃國昌"]
huang.head(1)
# Out:
#                                 post_id          page_id page_name  \
# 19360  449664581882455_1987236371392129  449664581882455       黃國昌
#
#       page_category                                            message  \
# 19360          政治人物  【記者會直播中】\n\n「全面修補制度漏洞 才能遏止虐童悲劇」記者會\n時間：2019年01...
#
#            story   type                                          permalink  \
# 19360  黃國昌的直播影片。  video  https://www.facebook.com/kcfor2016/videos/1987...
#
#                created_time_gmt  created_time_taipei  ... link_name  \
# 19360  2019-01-15T01:30:35+0000  2019-01-15T09:30:35  ...       NaN
#
#       link_description like_count  haha_count  love_count  angry_count  \
# 19360              NaN       2797           0           0            0
#
#        sad_count  wow_count  comment_count  share_count
# 19360          0          0            415          186
#
# [1 rows x 21 columns]

# %%
huang[huang.created_time_taipei == max(huang.created_time_taipei)]
# Out:
#                                 post_id          page_id page_name  \
# 20009  449664581882455_1359108877604683  449664581882455       黃國昌
#
#       page_category                                            message story  \
# 20009          政治人物  2020年強檔鉅獻：最值得您期待的卡司\n　\n一個不會被收買的團隊\n一股最有力的監督力量...   NaN
#
#         type                                          permalink  \
# 20009  video  https://www.facebook.com/449664581882455/posts...
#
#                created_time_gmt  created_time_taipei  ...  \
# 20009  2019-12-26T12:34:44+0000  2019-12-26T20:34:44  ...
#
#                  link_name link_description like_count  haha_count  \
# 20009  2020年強檔鉅獻：最值得您期待的卡司              NaN       6404           0
#
#        love_count  angry_count  sad_count  wow_count  comment_count  \
# 20009           0            0          0          0            182
#
#        share_count
# 20009          175
#
# [1 rows x 21 columns]

# %%
huang[huang.created_time_taipei == min(huang.created_time_taipei)]
# Out:
#                                 post_id          page_id page_name  \
# 19374  449664581882455_1091137621068478  449664581882455       黃國昌
#
#       page_category                                            message story  \
# 19374          政治人物  去年夏天，我直言批評：「屏東縣充斥著貪污、賄選的腐敗豬仔民代」，中國國民黨說要嚴肅回應。結果...   NaN
#
#        type                                          permalink  \
# 19374  link  https://www.facebook.com/449664581882455/posts...
#
#                created_time_gmt  created_time_taipei  ...  \
# 19374  2019-01-01T13:36:28+0000  2019-01-01T21:36:28  ...
#
#                                   link_name  \
# 19374  屏東地檢對30名當選人提當選無效之訴 含5議員、3鄉鎮長 | 聯合新聞網
#
#                                         link_description like_count  \
# 19374  屏東地檢署今針對5名縣議員、3名鄉鎮長及16名鄉鎮市民代表及6名村里長等總計30人，依公職人...       7554
#
#        haha_count  love_count  angry_count  sad_count  wow_count  \
# 19374           0           0            0          0          0
#
#        comment_count  share_count
# ...

# %%
huang['new_date'] = pd.to_datetime(huang['created_time_taipei']).dt.date
huang['month_year'] = pd.to_datetime(huang['new_date']).dt.to_period('M')
huang.head(1)
# Out:
# <ipython-input-6-9efa112c6955>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   huang['new_date'] = pd.to_datetime(huang['created_time_taipei']).dt.date
# <ipython-input-6-9efa112c6955>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   huang['month_year'] = pd.to_datetime(huang['new_date']).dt.to_period('M')
#                                 post_id          page_id page_name  \
# 19360  449664581882455_1987236371392129  449664581882455       黃國昌
#
# ...

# %%
results = huang.groupby('month_year').sum()
results
# Out:
#                       page_id  like_count  haha_count  love_count  \
# month_year
# 2019-01     13489937456473660      138766           0           0
# 2019-02     16637589529650852      116690           0           0
# 2019-03     21134235348475412      206760           0           0
# 2019-04     21134235348475412      147130           0           0
# 2019-05     19335577020945588      298779           0           0
# 2019-06     30577191568006988     1019906           0           0
# 2019-07     34624172804949092      596273           0           0
# 2019-08     22932893676005236      380519           0           0
# 2019-09     28328868658594708      361592           0           0
# 2019-10     33275179059301724      405859           0           0
# 2019-11     34174508223066636      802853           0           0
# 2019-12     35073837386831548      756092           0           0
#
#             angry_count  sad_count  wow_count  comment_count  share_count
# month_year
# ...

# %%
results.index.name = 'newhead'
results.reset_index(inplace=True)
results
# Out:
#     newhead            page_id  like_count  haha_count  love_count  \
# 0   2019-01  13489937456473660      138766           0           0
# 1   2019-02  16637589529650852      116690           0           0
# 2   2019-03  21134235348475412      206760           0           0
# 3   2019-04  21134235348475412      147130           0           0
# 4   2019-05  19335577020945588      298779           0           0
# 5   2019-06  30577191568006988     1019906           0           0
# 6   2019-07  34624172804949092      596273           0           0
# 7   2019-08  22932893676005236      380519           0           0
# 8   2019-09  28328868658594708      361592           0           0
# 9   2019-10  33275179059301724      405859           0           0
# 10  2019-11  34174508223066636      802853           0           0
# 11  2019-12  35073837386831548      756092           0           0
#
#     angry_count  sad_count  wow_count  comment_count  share_count
# ...

# %%
results['newhead'].map(str)
# Out:
# 0     2019-01
# 1     2019-02
# 2     2019-03
# 3     2019-04
# 4     2019-05
# 5     2019-06
# 6     2019-07
# 7     2019-08
# 8     2019-09
# 9     2019-10
# 10    2019-11
# 11    2019-12
# Name: newhead, dtype: object

# %%
import matplotlib.pyplot as plt

labels = results['newhead'].map(str)
width = 0.5       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)

ax.bar(labels, results['like_count'], width, label='like_count')
ax.bar(labels, results['share_count'], width, label='share_count', bottom=results['like_count'])
ax.bar(labels, results['comment_count'], width, label='comment_count', bottom=results['share_count']+results['like_count'])

ax.legend()

plt.show()

# %% [markdown]
# 第十屆立委選舉日，民國109年（2020年）1月11號舉行，相較於選前兩個月，六月讚數高之原因爲何？

# %%
June = huang[huang.month_year == "2019-06"]

# %%
results_june = June.groupby('new_date').sum()
results_june
# Out:
#                      page_id  like_count  haha_count  love_count  angry_count  \
# new_date
# 2019-06-03   899329163764910       22961           0           0            0
# 2019-06-04   449664581882455        8762           0           0            0
# 2019-06-05  1348993745647365       38574           0           0            0
# 2019-06-06   449664581882455       13537           0           0            0
# 2019-06-07   449664581882455       12938           0           0            0
# 2019-06-08  1348993745647365       30603           0           0            0
# 2019-06-09   899329163764910       30970           0           0            0
# 2019-06-10   449664581882455       14716           0           0            0
# 2019-06-12   449664581882455       17862           0           0            0
# 2019-06-13  1348993745647365      104429           0           0            0
# 2019-06-14   899329163764910       41812           0           0            0
# ...

# %%
results_june.index.name = 'newhead'
results_june.reset_index(inplace=True)
results_june
# Out:
#        newhead           page_id  like_count  haha_count  love_count  \
# 0   2019-06-03   899329163764910       22961           0           0
# 1   2019-06-04   449664581882455        8762           0           0
# 2   2019-06-05  1348993745647365       38574           0           0
# 3   2019-06-06   449664581882455       13537           0           0
# 4   2019-06-07   449664581882455       12938           0           0
# 5   2019-06-08  1348993745647365       30603           0           0
# 6   2019-06-09   899329163764910       30970           0           0
# 7   2019-06-10   449664581882455       14716           0           0
# 8   2019-06-12   449664581882455       17862           0           0
# 9   2019-06-13  1348993745647365      104429           0           0
# 10  2019-06-14   899329163764910       41812           0           0
# 11  2019-06-15   449664581882455       10838           0           0
# 12  2019-06-16  1348993745647365       60079           0           0
# ...

# %%
import matplotlib.pyplot as plt

labels = [str(i) for i in range(1,28)]

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)

ax.plot(labels, results_june['like_count'])
ax.plot(labels, results_june['share_count'])
ax.plot(labels, results_june['comment_count'])

ax.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# 2019年6月10日和6月20日的文章獲得高關注，內容為何？

# %%
huang['new_date']=huang['new_date'].map(str)
huang[huang['new_date'] == "2019-06-10"]
# Out:
# <ipython-input-15-d4ff4a4f86cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   huang['new_date']=huang['new_date'].map(str)
#                                 post_id          page_id page_name  \
# 19567  449664581882455_1193196810862558  449664581882455       黃國昌
#
#       page_category                                            message story  \
# 19567          政治人物  請屏東縣府別再說謊\n\n針對屏東縣府長期縱容民進黨議員周碧雲的違法養雞場，\n屏東縣府一直...   NaN
#
#         type                                          permalink  \
# 19567  photo  https://www.facebook.com/449664581882455/posts...
#
#                created_time_gmt  created_time_taipei  ... like_count  \
# 19567  2019-06-10T00:34:45+0000  2019-06-10T08:34:45  ...      14716
#
# ...

# %%
temp = huang[huang['new_date'] == "2019-06-20"]
temp[temp.like_count == max(temp.like_count)]
# Out:
#                                 post_id          page_id page_name  \
# 19614  449664581882455_1201005813414991  449664581882455       黃國昌
#
#       page_category                                            message story  \
# 19614          政治人物  剛剛有統促黨的，跑來立法院向我抗議：\n\n「你憑什麼強迫CNN一定要關閉中天？」\n\n阿...   NaN
#
#         type                                          permalink  \
# 19614  video  https://www.facebook.com/449664581882455/posts...
#
#                created_time_gmt  created_time_taipei  ... like_count  \
# 19614  2019-06-20T03:02:33+0000  2019-06-20T11:02:33  ...      18761
#
#       haha_count love_count  angry_count  sad_count  wow_count  comment_count  \
# 19614          0          0            0          0          0           2627
#
#        share_count    new_date  month_year
# 19614         1583  2019-06-20     2019-06
#
# [1 rows x 23 columns]

# %%
temp[temp.like_count == min(temp.like_count)]
# Out:
#                                 post_id          page_id page_name  \
# 19615  449664581882455_1200967213418851  449664581882455       黃國昌
#
#       page_category                                            message story  \
# 19615          政治人物  小啟：今晚YT直播時間改為22:00\n\n本預定今晚於21:00開的直播，經網友提醒發現與...   NaN
#
#         type                                          permalink  \
# 19615  photo  https://www.facebook.com/449664581882455/posts...
#
#                created_time_gmt  created_time_taipei  ... like_count  \
# 19615  2019-06-20T01:41:00+0000  2019-06-20T09:41:00  ...       2872
#
#       haha_count love_count  angry_count  sad_count  wow_count  comment_count  \
# 19615          0          0            0          0          0             76
#
#        share_count    new_date  month_year
# 19615           43  2019-06-20     2019-06
#
# [1 rows x 23 columns]

# %% [markdown]
# 2019-06-10 質疑屏東縣府違法包庇縣議員養雞場
#
# 2019-06-20 與統促黨唇槍舌戰

# %% [markdown]
# 2019-06-12 發文是六月中獲得關注最少，為何？

# %%
huang[huang['new_date'] == "2019-06-12"]
# Out:
#                                 post_id          page_id page_name  \
# 19566  449664581882455_1194866357362270  449664581882455       黃國昌
#
#       page_category                                            message story  \
# 19566          政治人物  因為堅持，所以看到希望。\n拒絕送中，香港加油！\n\nhttps://www.cna.co...   NaN
#
#        type                                          permalink  \
# 19566  link  https://www.facebook.com/449664581882455/posts...
#
#                created_time_gmt  created_time_taipei  ... like_count  \
# 19566  2019-06-12T04:50:13+0000  2019-06-12T12:50:13  ...      17862
#
#       haha_count love_count  angry_count  sad_count  wow_count  comment_count  \
# 19566          0          0            0          0          0            271
#
#        share_count    new_date  month_year
# 19566          234  2019-06-12     2019-06
#
# [1 rows x 23 columns]

# %% [markdown]
# 2019-02 發文內容獲得的關注最少，內容為何

# %%
results_feb = huang[huang.month_year == "2019-02"].groupby('new_date').sum()
results_feb[results_feb.like_count == min(results_feb.like_count)]
# Out:
#                     page_id  like_count  haha_count  love_count  angry_count  \
# new_date
# 2019-02-15  449664581882455        1951           0           0            0
#
#             sad_count  wow_count  comment_count  share_count
# new_date
# 2019-02-15          0          0            128           75

# %%
pd.set_option('display.max_colwidth', None)
showlink = huang[huang.new_date == "2019-02-15"].permalink.to_string()
print(showlink)
# Out:
# 19426    https://www.facebook.com/449664581882455/posts/1119491298233110/

# %% [markdown]
# 內容為防制酒駕

# %%
print(politics[politics.姓名 == "黃 國 昌"].政見.to_string())
# Out:
# 21    一、改善就業環境，提升勞動條件 １.制定最低生活工資專法，保障勞工生活水準 ２.貫徹周休二日，不當過勞之島 ３.創造公共就業，增加青年就業 ４.建構友善勞工的權利救濟機制 二、落實年金改革，讓下一代有未來 １.建立全民基礎年金，保障銀髮生活品質 ２.逐步縮小不同業別間的所得替代率 ３.打造收支平衡、不債留子孫的年金制度 三、實現人民作主的新政治 １.調降罷免權及公民投票權的門檻，還權於民 ２.推動憲政改革，強化人權保障，落實責任政治 ３.制訂「吹哨者保護法」，鼓勵人民揭弊 四、打造透明專業的新國會 １.黨團協商公開透明化，建立以委員會為中心的 專業審查，終結密室協商 ２.強化立法院監督職權，建立國會聽證制度 ３.建立國會頻道，強化公眾監督 ４.依太陽花運動的民間版原則，建立兩岸協議監 督機制 五、建構永續生活環境 １.立即廢止核四，核一、核二如期除役、反對核 廢料露天貯存於北海岸 ２.強化空氣、水及土壤污染管制，建立空污總量 管制 ３.制定「環境稅法」，貫徹「污染者付費」原則 ，協助產業升級轉型 六、健全交通運輸、提昇生活品質 １.改善汐止及社后地區交通，增設聯外道路橋樑 ２.要求行政院儘速核定民生汐止線，加速台鐵捷 運化 ３.打造「瑞平雙貢」環狀交通路網 ４.人口密集區及觀光景點增設停車場 七、創造新北市七星區「在地經濟、在地就業、在地 生活」 １.連結汐止及南港、內湖科技園區，創造在地經 濟 ２.修改過時法令，活化金山、萬里及四鄉鎮觀光 產業，鼓勵年輕人在地就業 ３.重現文化風華，打造在地休閒
